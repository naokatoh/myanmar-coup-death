# %%
import pandas as pd

# %%
df = pd.read_csv("coup.csv")

# %%
df.head()
# Out:
#   No.                            Name Sex   Age          Father's name  \
# 0   1   Na Pwar (aka) Ko \nNyi Nyi Oo   M  32.0             U Hla Ngwe
# 1   2        Mya Thwet Thwet \nKhaing   F  21.0             U Min Lwin
# 2   3                Nay Nay Win Htet   M  18.0                Unknown
# 3   4  Thet Naing Win \n(aka) Min Min   M  37.0  U Maung San 20-Feb-21
# 4   5                     Wai Yan Tun   M  16.0                Unknown
#
#   Date of Incident Deceased Date Organization  \
# 0        08-Feb-21      8-Feb-21     Civilian
# 1        09-Feb-21     19-Feb-21      Student
# 2        15-Feb-21     15-Feb-21     Civilian
# 3              NaN     20-Feb-21     Civilian
# 4        20-Feb-21     20-Feb-21     Civilian
#
#                                Place of Incidents  \
# 0                                        Mandalay
# 1  Near Tha Pyay \nGone \nRoundabout, \nNaypyitaw
# 2                   Myeik, \nTanintharyi \nRegion
# 3                    Kannar Road, \nMandalay City
# ...

# %%
df.date_of_incident = pd.to_datetime(df['Date of Incident'],format='%d-%b-%y',errors='coerce')
df.deceased_date = pd.to_datetime(df['Deceased Date'],format='%d-%b-%y',errors='coerce')

# %%
df.columns = df.columns.str.replace('/','_').str.lower()

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1678 entries, 0 to 1677
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   no.                 1676 non-null   object
#  1   name                1656 non-null   object
#  2   sex                 1632 non-null   object
#  3   age                 1316 non-null   float64
#  4   father's name       1673 non-null   object
#  5   date of incident    1664 non-null   object
#  6   deceased date       1641 non-null   object
#  7   organization        1676 non-null   object
#  8   place of incidents  1548 non-null   object
#  9   home address        1157 non-null   object
#  10  township            1584 non-null   object
#  11  states_regions      1628 non-null   object
#  12  remarks             1401 non-null   object
#  13  date_of_incident    1649 non-null   datetime64[ns]
#  14  deceased_date       1639 non-null   datetime64[ns]
# ...

# %%
df[df.deceased_date =="2021-02-04"]
# Out:
# Empty DataFrame
# Columns: [no., name, sex, age, father's name, date of incident, deceased date, organization, place of incidents, home address, township, states_regions, remarks, date_of_incident, deceased_date]
# Index: []

# %%
df.sort_values("deceased_date")
# Out:
#        no.                            name sex   age          father's name  \
# 0        1   Na Pwar (aka) Ko \nNyi Nyi Oo   M  32.0             U Hla Ngwe
# 2        3                Nay Nay Win Htet   M  18.0                Unknown
# 1        2        Mya Thwet Thwet \nKhaing   F  21.0             U Min Lwin
# 3        4  Thet Naing Win \n(aka) Min Min   M  37.0  U Maung San 20-Feb-21
# 4        5                     Wai Yan Tun   M  16.0                Unknown
# ...    ...                             ...  ..   ...                    ...
# 1430  1431                     Maung Nyunt   M   NaN         Unknown \nName
# 1440  1441                    Aung Lwin Oo   M   NaN         Unknown \nName
# 1441  1442                         Min Min   M  30.0         Unknown \nName
# 1442  1443                        San Aung   M  52.0         Unknown \nName
# 1605  1606                       Thein Tun   M   NaN         Unknown \nName
#
#      date of incident deceased date organization  \
# ...

# %%
df[df.states_regions == "Sagaing"].resample("W", on="date_of_incident").size().plot()
# Out:
# <AxesSubplot:xlabel='date_of_incident'>

# %%
df[df.states_regions == "Yangon"].resample("W", on="date_of_incident").size().plot()
# Out:
# <AxesSubplot:xlabel='date_of_incident'>

# %%
df[df.states_regions == "Mandalay"].resample("W", on="date_of_incident").size().plot()
# Out:
# <AxesSubplot:xlabel='date_of_incident'>

# %%
df.states_regions.unique()
# Out:
# array(['Mandalay', 'Naypyitaw', 'Tanintharyi', 'Yangon', 'Mon', 'Bago',
#        'Magway', nan, 'Sagaing', 'Kachin', 'Ayeyarwady', 'Shan', 'Kayah',
#        'Chin', 'Rakhine', 'Karen', 'Kayin', 'Arrawaddy'], dtype=object)

# %%
df[df.states_regions == "Tanintharyi"].resample("W", on="date_of_incident").size().plot()
# Out:
# <AxesSubplot:xlabel='date_of_incident'>

# %%
df.resample("D", on="date_of_incident").size().plot()
# Out:
# <AxesSubplot:xlabel='date_of_incident'>

# %%
df[df.deceased_date < "2021-04-12"].resample("D", on="deceased_date").size().plot()
# Out:
# <AxesSubplot:xlabel='deceased_date'>

# %%
df.resample("D", on="date_of_incident").size().sort_values().tail(10)
# Out:
# date_of_incident
# 2021-09-09     20
# 2021-03-28     21
# 2021-03-03     25
# 2021-03-29     28
# 2021-04-07     29
# 2021-04-09     29
# 2022-03-08     30
# 2021-03-15     33
# 2021-03-14    115
# 2021-03-27    163
# dtype: int64

# %%
df[(df.deceased_date <= "2021-03-31") &(df.deceased_date > "2021-02-28")].resample("D", on="deceased_date").size().sum()
# Out:
# 539

# %%
df[(df.deceased_date <= "2021-02-28") &(df.deceased_date > "2021-02-01")].resample("D", on="deceased_date").size().sum()
# Out:
# 23

# %%
monthly =pd.DataFrame(df.resample("M", on="date_of_incident").size())

# %%
monthly.to_csv("monthly.csv")
monthly
# Out:
#                     0
# date_of_incident
# 2021-02-28         27
# 2021-03-31        550
# 2021-04-30        143
# 2021-05-31         79
# 2021-06-30         47
# 2021-07-31         91
# 2021-08-31         58
# 2021-09-30        100
# 2021-10-31         84
# 2021-11-30         64
# 2021-12-31        103
# 2022-01-31         78
# 2022-02-28         82
# 2022-03-31        113
# 2022-04-30         30

# %%
df[(df.date_of_incident <= "2022-03-31") &(df.date_of_incident > "2022-02-28")]["place of incidents"].value_counts()
# Out:
# In the Village                                                                     44
# Lat Pan Taw \nVillage \nMonastery                                                  13
# In The Farm                                                                        11
# On The Road                                                                         6
# In The House                                                                        6
# Kyauk Taung \nVillage                                                               3
# In the Farm                                                                         3
# Public \nresthouse                                                                  2
# In the \nMonastery                                                                  2
# Near  Warisu \nPalai Village                                                        2
# In the jungle \nnear Wai La \nMu Village                                            2
# ...

# %%
df[(df.date_of_incident <= "2022-03-31") &(df.date_of_incident > "2022-02-28")& (df["place of incidents"].str.contains("Lat Pan Taw"))]
# Out:
#        no.              name sex   age      father's name date of incident  \
# 1556  1557       Moh Moh Win   F  30.0         U Kyar Win         8-Mar-22
# 1557  1558  Myat Bhone Naing   M   7.0  Daw Mot \nMot Win         8-Mar-22
# 1558  1559   Swan Htet Naing   M   9.0  Daw Mot \nMot Win         8-Mar-22
# 1559  1560         Thein Hla   F  70.0     Unknown \nName         8-Mar-22
# 1560  1561         Tin Nyunt   F  93.0     Unknown \nName         8-Mar-22
# 1561  1562        Aye Thaung   F  62.0     Unknown \nName         8-Mar-22
# 1562  1563        Than Maung   M  70.0     Unknown \nName         8-Mar-22
# 1563  1564          Hla Pyae   F  78.0     Unknown \nName         8-Mar-22
# 1564  1565        Than Nyunt   F  78.0     Unknown \nName         8-Mar-22
# 1565  1566         Sein Tint   F  68.0     Unknown \nName         8-Mar-22
# 1566  1567       Thein Maung   M  70.0     Unknown \nName         8-Mar-22
# ...

# %%
df[(df.deceased_date <= "2022-03-31") &(df.deceased_date > "2022-02-28")].resample("D", on="date_of_incident").size().sort_values()
# Out:
# date_of_incident
# 2021-09-20     0
# 2021-11-11     0
# 2021-11-10     0
# 2021-11-09     0
# 2021-11-08     0
#               ..
# 2022-03-19     5
# 2022-03-12     5
# 2022-03-04     9
# 2022-03-05    18
# 2022-03-08    30
# Length: 382, dtype: int64

# %%
df[df.deceased_date == "2022-03-08"]
# Out:
#        no.                  name  sex   age      father's name  \
# 1556  1557           Moh Moh Win    F  30.0         U Kyar Win
# 1557  1558      Myat Bhone Naing    M   7.0  Daw Mot \nMot Win
# 1558  1559       Swan Htet Naing    M   9.0  Daw Mot \nMot Win
# 1559  1560             Thein Hla    F  70.0     Unknown \nName
# 1560  1561             Tin Nyunt    F  93.0     Unknown \nName
# 1561  1562            Aye Thaung    F  62.0     Unknown \nName
# 1562  1563            Than Maung    M  70.0     Unknown \nName
# 1563  1564              Hla Pyae    F  78.0     Unknown \nName
# 1564  1565            Than Nyunt    F  78.0     Unknown \nName
# 1565  1566             Sein Tint    F  68.0     Unknown \nName
# 1566  1567           Thein Maung    M  70.0     Unknown \nName
# 1567  1568            Ohn Hlaing    M  70.0     Unknown \nName
# 1568  1569                  Thin    F   NaN     Unknown \nName
# 1575  1576          Unknown Name    M   7.0          U Hla Tun
# ...

# %%
df[(df.deceased_date <= "2021-02-28") &(df.deceased_date > "2021-01-31")].states_regions.value_counts()
# Out:
# Mandalay       8
# Tanintharyi    5
# Yangon         4
# Bago           2
# Naypyitaw      1
# Mon            1
# Magway         1
# Name: states_regions, dtype: int64

# %%
df[(df.date_of_incident <= "2021-02-28") &(df.date_of_incident > "2021-01-31")].head()
# Out:
#   no.                           name sex   age father's name date of incident  \
# 0   1  Na Pwar (aka) Ko \nNyi Nyi Oo   M  32.0    U Hla Ngwe        08-Feb-21
# 1   2       Mya Thwet Thwet \nKhaing   F  21.0    U Min Lwin        09-Feb-21
# 2   3               Nay Nay Win Htet   M  18.0       Unknown        15-Feb-21
# 4   5                    Wai Yan Tun   M  16.0       Unknown        20-Feb-21
# 5   6                        Kyi Soe   M  48.0       Unknown        20-Feb-21
#
#   deceased date organization                              place of incidents  \
# 0      8-Feb-21     Civilian                                        Mandalay
# 1     19-Feb-21      Student  Near Tha Pyay \nGone \nRoundabout, \nNaypyitaw
# 2     15-Feb-21     Civilian                   Myeik, \nTanintharyi \nRegion
# 4     20-Feb-21     Civilian                    Kannar Road, \nMandalay City
# 5     20-Feb-21     Civilian                    Strand Road, \nMandalay City
#
# ...

# %%
# March & Apr
df[(df.date_of_incident <= "2021-04-30") &(df.date_of_incident > "2021-02-28")].head()
# Out:
#    no.                                    name sex   age  \
# 24  25           Thiha Zaw (aka) \nNaung Naung   M  16.0
# 25  26    Zin Ko Ko Thaw \n(aka) Zin Ko Ko Zaw   M  22.0
# 26  27         Myo Naing Linn \n(aka) Pho Linn   M  39.0
# 27  28  Kyal Sin (aka) Kyar \nShie (aka) Angel   F  19.0
# 28  29                            Nay Myo Aung   M  16.0
#
#                            father's name date of incident deceased date  \
# 24  U Soe Win + \nDaw Thin \nThin Khaing         2-Mar-21      2-Mar-21
# 25             U Phoe Wa + \nDaw Ma Htar         3-Mar-21      3-Mar-21
# 26                               Unknown         3-Mar-21      3-Mar-21
# 27                   Daw Aye Aye \nMyint         3-Mar-21      3-Mar-21
# 28                             U Linn Oo         3-Mar-21      3-Mar-21
#
#    organization         place of incidents  \
# 24      Student    Near Satthwar \nVillage
# 25      Student          Myingyan \nStrike
# 26     Civilian  84 Street and \n30 Street
# ...

# %%
df[(df.place_of_incidents <= "2021-04-30") &(df.place of incidents > "2021-02-28")&(df.organization.str.contains("Student"))]
# Out:
#      no.                                    name sex   age  \
# 23    24                         Kaung Pyae Sone   M  20.0
# 24    25           Thiha Zaw (aka) \nNaung Naung   M  16.0
# 25    26    Zin Ko Ko Thaw \n(aka) Zin Ko Ko Zaw   M  22.0
# 27    28  Kyal Sin (aka) Kyar \nShie (aka) Angel   F  19.0
# 28    29                            Nay Myo Aung   M  16.0
# ..   ...                                     ...  ..   ...
# 661  662                             Bo Bo Naing   M   NaN
# 662  663                         Han Thwin Khant   M   NaN
# 704  705                              Jhonjulian   M  22.0
# 705  706                           Hein Min Latt   M  16.0
# 707  708    Kaung Htet Naing \n(aka) Kaung Kaung   M  22.0
#
#                                          father's name date of incident  \
# 23                                             Unknown        28-Feb-21
# 24                U Soe Win + \nDaw Thin \nThin Khaing         2-Mar-21
# ...

# %%
df[(df.deceased_date <= "2021-04-30") &(df.deceased_date > "2021-02-28")&(df.remarks.str.contains("gunshot"))]
# Out:
#      no.                                         name sex   age  \
# 23    24                              Kaung Pyae Sone   M  20.0
# 35    36                 Kay Za Win @ Chan \nThar Swe   M  39.0
# 36    37                     Wai Yan (aka) Kan \nChun   M  25.0
# 44    45           Sithu Shein (aka) \nMyat Thu Shein   M  18.0
# 51    52                                 Naing Min Ko   M  20.0
# ..   ...                                          ...  ..   ...
# 629  630                                     San Linn   M  37.0
# 630  631                                   Khant Phyo   M  25.0
# 631  632                                 Unknown Name   M   NaN
# 638  639                                      Myo Gyi   M  32.0
# 709  710  Zaw Shein (aka) \nEikyarkway (aka) \nEikway   M  40.0
#
#                     father's name date of incident deceased date  \
# 23                        Unknown        28-Feb-21     14-Mar-21
# ...

# %%
df[(df.deceased_date <= "2021-04-30") &(df.deceased_date > "2021-02-28")&(df.remarks.str.contains("shot"))]
# Out:
#      no.                                               name sex   age  \
# 23    24                                    Kaung Pyae Sone   M  20.0
# 29    30                Myint Myint Zin \n(aka) Kyi Lin Aye   F  36.0
# 30    31                                  Kyawt Nandar Aung   F  26.0
# 35    36                       Kay Za Win @ Chan \nThar Swe   M  39.0
# 36    37                           Wai Yan (aka) Kan \nChun   M  25.0
# ..   ...                                                ...  ..   ...
# 707  708               Kaung Htet Naing \n(aka) Kaung Kaung   M  22.0
# 709  710        Zaw Shein (aka) \nEikyarkway (aka) \nEikway   M  40.0
# 711  712  Tg. Felix Thang \nMuan Lian ​\nမမာင ထန ်းမွမ ်...   M  20.0
# 713  714                                      Nyi Nyi Maung   M  32.0
# 714  715                                            San Paw   M   NaN
#
#                                          father's name date of incident  \
# ...

# %%
df[(df.deceased_date <= "2021-04-30") &(df.deceased_date > "2021-02-28")&(df.age <= 10)]
# Out:
#      no.           name sex  age father's name date of incident deceased date  \
# 311  312  Khin Myo Chit   F  7.0       Unknown        23-Mar-21     23-Mar-21
# 424  425   Unknown Name   M  9.0       Unknown        27-Mar-21     27-Mar-21
#
#     organization place of incidents               home address  township  \
# 311      Student       In The House  52(C) 105 106, \nMandalay  Mandalay
# 424     Civilian      Monywa Strike                        NaN    Monywa
#
#     states_regions                                            remarks  \
# 311       Mandalay  On the evening of March 23, the armed wing of ...
# 424        Sagaing                                                NaN
#
#     date_of_incident deceased_date
# 311       2021-03-23    2021-03-23
# 424       2021-03-27    2021-03-27

# %%
df[(df.date_of_incident <= "2021-04-30") &(df.date_of_incident > "2021-02-28")&(df.age >= 10)&(df.age <= 30)]
# Out:
#        no.                                               name sex   age  \
# 24      25                      Thiha Zaw (aka) \nNaung Naung   M  16.0
# 25      26               Zin Ko Ko Thaw \n(aka) Zin Ko Ko Zaw   M  22.0
# 27      28             Kyal Sin (aka) Kyar \nShie (aka) Angel   F  19.0
# 28      29                                       Nay Myo Aung   M  16.0
# 30      31                                  Kyawt Nandar Aung   F  26.0
# ...    ...                                                ...  ..   ...
# 704    705                                         Jhonjulian   M  22.0
# 705    706                                      Hein Min Latt   M  16.0
# 707    708               Kaung Htet Naing \n(aka) Kaung Kaung   M  22.0
# 711    712  Tg. Felix Thang \nMuan Lian ​\nမမာင ထန ်းမွမ ်...   M  20.0
# 1233  1234                                   George Maung Nge   M  17.0
#
#                                           father's name date of incident  \
# ...

# %%
df[(df.date_of_incident <= "2021-04-30") &(df.date_of_incident > "2021-02-28")&(df.age >= 10)&(df.age <= 30)].remarks.unique()
# Out:
# array(['He was killed when the military came into his road and opened fire.',
#        'Shot in the head with gunfire',
#        'Kyal Sin voted for the first time in the 2020 election. She was one of the young people who took to the streets in the wake of the February 1 military coup. She died while actively participating in the protests. Contact phone number She also posted about her body donation on social media.On March 3, security forces violently cracked down on protesters at 84th and 30th Streets in Mandalay, killing her in the head. On March 5, the coup regime unearthed her grave at Aye Yeik Nyein Cemetery and re-operated on her body.',
#        nan,
# ...

# %%
df[(df.date_of_incident <= "2021-2-28") &(df.date_of_incident > "2021-01-31")&(df.age >= 10)&(df.age <= 30)].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13 entries, 1 to 23
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   no.                 13 non-null     object
#  1   name                13 non-null     object
#  2   sex                 13 non-null     object
#  3   age                 13 non-null     float64
#  4   father's name       13 non-null     object
#  5   date of incident    13 non-null     object
#  6   deceased date       13 non-null     object
#  7   organization        13 non-null     object
#  8   place of incidents  13 non-null     object
#  9   home address        10 non-null     object
#  10  township            12 non-null     object
#  11  states_regions      12 non-null     object
#  12  remarks             13 non-null     object
#  13  date_of_incident    13 non-null     datetime64[ns]
#  14  deceased_date       13 non-null     datetime64[ns]
# ...

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   no.                 0 non-null      object
#  1   name                0 non-null      object
#  2   sex                 0 non-null      object
#  3   age                 0 non-null      float64
#  4   father's name       0 non-null      object
#  5   date of incident    0 non-null      object
#  6   deceased date       0 non-null      object
#  7   organization        0 non-null      object
#  8   place of incidents  0 non-null      object
#  9   home address        0 non-null      object
#  10  township            0 non-null      object
#  11  states_regions      0 non-null      object
#  12  remarks             0 non-null      object
#  13  date_of_incident    0 non-null      datetime64[ns]
#  14  deceased_date       0 non-null      datetime64[ns]
# ...

# %%
df[(df.date_of_incident <= "2021-2-28") &(df.date_of_incident > "2021-01-31")].states_regions.value_counts()
# Out:
# Mandalay       7
# Yangon         6
# Tanintharyi    5
# Bago           3
# Naypyitaw      1
# Mon            1
# Magway         1
# Shan           1
# Name: states_regions, dtype: int64

# %%
df_1 = df[(df.date_of_incident <= "2021-2-28") &(df.date_of_incident > "2021-01-31")]
df_2 =df[(df.date_of_incident <= "2021-4-30") &(df.date_of_incident > "2021-02-28")]
df_3 =df[(df.date_of_incident <= "2021-8-30") &(df.date_of_incident > "2021-04-30")]
df_4 =df[(df.date_of_incident <= "2021-12-31") &(df.date_of_incident > "2021-08-30")]
df_5 =df[(df.date_of_incident <= "2022-4-15") &(df.date_of_incident > "2021-12-31")]

# %%
df_1[(df_1.states_regions =="Yangon")|(df_1.states_regions =="Mandalay")].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13 entries, 0 to 895
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   no.                 13 non-null     object
#  1   name                13 non-null     object
#  2   sex                 13 non-null     object
#  3   age                 13 non-null     float64
#  4   father's name       13 non-null     object
#  5   date of incident    13 non-null     object
#  6   deceased date       13 non-null     object
#  7   organization        13 non-null     object
#  8   place of incidents  13 non-null     object
#  9   home address        8 non-null      object
#  10  township            12 non-null     object
#  11  states_regions      13 non-null     object
#  12  remarks             13 non-null     object
#  13  date_of_incident    13 non-null     datetime64[ns]
#  14  deceased_date       13 non-null     datetime64[ns]
# ...

# %%
df_2[(df_2.states_regions =="Yangon")|(df_2.states_regions =="Mandalay")].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 369 entries, 25 to 713
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   no.                 369 non-null    object
#  1   name                369 non-null    object
#  2   sex                 357 non-null    object
#  3   age                 311 non-null    float64
#  4   father's name       367 non-null    object
#  5   date of incident    369 non-null    object
#  6   deceased date       369 non-null    object
#  7   organization        369 non-null    object
#  8   place of incidents  352 non-null    object
#  9   home address        195 non-null    object
#  10  township            355 non-null    object
#  11  states_regions      369 non-null    object
#  12  remarks             186 non-null    object
#  13  date_of_incident    369 non-null    datetime64[ns]
#  14  deceased_date       369 non-null    datetime64[ns]
# ...

# %%
df_5[(df_5.states_regions =="Yangon")|(df_5.states_regions =="Mandalay")].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29 entries, 1350 to 1673
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   no.                 29 non-null     object
#  1   name                27 non-null     object
#  2   sex                 29 non-null     object
#  3   age                 17 non-null     float64
#  4   father's name       29 non-null     object
#  5   date of incident    29 non-null     object
#  6   deceased date       29 non-null     object
#  7   organization        29 non-null     object
#  8   place of incidents  29 non-null     object
#  9   home address        24 non-null     object
#  10  township            27 non-null     object
#  11  states_regions      29 non-null     object
#  12  remarks             29 non-null     object
#  13  date_of_incident    29 non-null     datetime64[ns]
#  14  deceased_date       29 non-null     datetime64[ns]
# ...

# %%
df_5.states_regions.value_counts(normalize=True)
# Out:
# Sagaing        0.568106
# Magway         0.129568
# Mandalay       0.069767
# Kayin          0.036545
# Kayah          0.033223
# Yangon         0.026578
# Tanintharyi    0.026578
# Mon            0.026578
# Kachin         0.023256
# Bago           0.019934
# Shan           0.016611
# Chin           0.013289
# Karen          0.003322
# Arrawaddy      0.003322
# Ayeyarwady     0.003322
# Name: states_regions, dtype: float64

# %%
df_5.organization.value_counts()
# Out:
# Civilian                                                                    243
# LPDF                                                                         14
# Student                                                                       5
# PDF (Member of Tigyaing PDF)                                                  5
# Volunteer                                                                     4
# Farmer                                                                        4
# PDF                                                                           4
# Civilian (IDPs)                                                               3
# Monk                                                                          3
# PDF (Local)                                                                   3
# CNDF                                                                          2
# Civilian (Village Self-Defense Team Leader)                                   2
# ...

# %%
df_5[df_5.organization.str.contains("PDF|CNDF ")].states_regions.value_counts()
# Out:
# Sagaing    23
# Magway      4
# Name: states_regions, dtype: int64

# %% [markdown]
# df_2.organization.value_counts()

# %%
df_3.states_regions.value_counts()
# Out:
# Sagaing        114
# Mandalay        31
# Magway          20
# Yangon          20
# Kayah           20
# Bago            14
# Shan            12
# Chin            11
# Kachin          10
# Tanintharyi      6
# Ayeyarwady       6
# Mon              3
# Naypyitaw        1
# Name: states_regions, dtype: int64

# %%
df_4.states_regions.value_counts()
# Out:
# Sagaing        163
# Magway          55
# Mandalay        36
# Kayah           18
# Yangon          17
# Tanintharyi     13
# Chin            11
# Bago             9
# Shan             9
# Mon              5
# Ayeyarwady       5
# Kachin           3
# Naypyitaw        3
# Name: states_regions, dtype: int64

# %%
df_4.states_regions.value_counts(normalize = True)*100
# Out:
# Sagaing        46.974063
# Magway         15.850144
# Mandalay       10.374640
# Kayah           5.187320
# Yangon          4.899135
# Tanintharyi     3.746398
# Chin            3.170029
# Bago            2.593660
# Shan            2.593660
# Mon             1.440922
# Ayeyarwady      1.440922
# Kachin          0.864553
# Naypyitaw       0.864553
# Name: states_regions, dtype: float64

# %%
df_5.states_regions.value_counts(normalize=True)*100
# Out:
# Sagaing        56.810631
# Magway         12.956811
# Mandalay        6.976744
# Kayin           3.654485
# Kayah           3.322259
# Yangon          2.657807
# Tanintharyi     2.657807
# Mon             2.657807
# Kachin          2.325581
# Bago            1.993355
# Shan            1.661130
# Chin            1.328904
# Karen           0.332226
# Arrawaddy       0.332226
# Ayeyarwady      0.332226
# Name: states_regions, dtype: float64

# %%
df.states_regions.value_counts()
# Out:
# Sagaing        557
# Mandalay       265
# Yangon         256
# Magway         145
# Bago            89
# Tanintharyi     61
# Kayah           57
# Shan            56
# Chin            38
# Kachin          33
# Ayeyarwady      26
# Mon             22
# Kayin           11
# Naypyitaw        9
# Rakhine          1
# Karen            1
# Arrawaddy        1
# Name: states_regions, dtype: int64

# %%
df.date_of_incident.isnull().value_counts()
# Out:
# False    1649
# True       29
# Name: date_of_incident, dtype: int64

# %%
df_4[df_4.organization.str.contains("PDF",na=False)].organization.value_counts().sum()
# Out:
# 9

# %%
# 2021-09-09 
# 2021-12-07 

df_4[df_4.date_of_incident == "2021-12-07"]
# Out:
#                no.                         name sex   age   father's name  \
# 1250          1251                    Arkar Soe   M  14.0  Unknown \nName
# 1251          1252                   San Min Oo   M  17.0  Unknown \nName
# 1252          1253              Than Myint Aung   M  17.0  Unknown \nName
# 1253          1254                 Unknown Name   M  17.0  Unknown \nName
# 1254          1255                    Kyaw Thet   M  17.0  Unknown \nName
# 1255          1256                  Chit Nan Oo   M  19.0  Unknown \nName
# 1256          1257                     Win Kyaw   M  20.0  Unknown \nName
# 1257          1258  Htet Ko (aka) Htet \nKo Win   M  22.0  Unknown \nName
# 1258          1259                  Zin Min Tun   M  22.0  Unknown \nName
# 1259          1260                   Tint Naing   M  30.0  Unknown \nName
# 1260          1261                          Soe   M  40.0  Unknown \nName
# 1261  1262 Win Kyi                          NaN  FF  65.0  Unknown \nName
# ...

# %%
df2_YM = df_2[(df_2.states_regions =="Yangon")|(df_2.states_regions =="Mandalay")]
df2_YM.info()
df2_YM[(df2_YM.age>=10)&(df2_YM.age<=30)].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 369 entries, 25 to 713
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   no.                 369 non-null    object
#  1   name                369 non-null    object
#  2   sex                 357 non-null    object
#  3   age                 311 non-null    float64
#  4   father's name       367 non-null    object
#  5   date of incident    369 non-null    object
#  6   deceased date       369 non-null    object
#  7   organization        369 non-null    object
#  8   place of incidents  352 non-null    object
#  9   home address        195 non-null    object
#  10  township            355 non-null    object
#  11  states_regions      369 non-null    object
#  12  remarks             186 non-null    object
#  13  date_of_incident    369 non-null    datetime64[ns]
#  14  deceased_date       369 non-null    datetime64[ns]
# ...

# %%
df_2[(df_2.age>=10)&(df_2.age<=30)].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 314 entries, 24 to 1233
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   no.                 314 non-null    object
#  1   name                314 non-null    object
#  2   sex                 309 non-null    object
#  3   age                 314 non-null    float64
#  4   father's name       312 non-null    object
#  5   date of incident    314 non-null    object
#  6   deceased date       314 non-null    object
#  7   organization        314 non-null    object
#  8   place of incidents  292 non-null    object
#  9   home address        166 non-null    object
#  10  township            301 non-null    object
#  11  states_regions      294 non-null    object
#  12  remarks             203 non-null    object
#  13  date_of_incident    314 non-null    datetime64[ns]
#  14  deceased_date       314 non-null    datetime64[ns]
# ...

# %%
df_3.remarks.str.contains("shot",case=False).value_counts()
# Out:
# True     153
# False     90
# Name: remarks, dtype: int64

# %%
df_3[df_3.age<10]
# Out:
#      no.              name sex  age      father's name date of incident  \
# 827  828  Moe Thandar Aung   F  1.0  U Than Soe \nAung        19-Jun-21
# 945  946      Unknown Name   F  1.0     U Nyein \nChan        12-Aug-21
#
#     deceased date organization        place of incidents home address  \
# 827     19-Jun-21     Civilian  Keng Tung \n(Kyaingtong)          NaN
# 945     12-Aug-21     Civilian                   At Home       4 Ward
#
#                      township states_regions  \
# 827  Keng Tung \n(Kyaingtong)           Shan
# 945                  Myingyan       Mandalay
#
#                                                remarks date_of_incident  \
# 827  On the night of June 19, a resident form Kyain...       2021-06-19
# 945  On the morning of August 12 in Myingyan Townsh...       2021-08-12
#
#     deceased_date
# 827    2021-06-19
# 945    2021-08-12

# %%
df_3[df_3["place of incidents"].str.contains("Kani",na=False)].remarks.unique()
# Out:
# array(['12 men who were arrested by terrorist junta’s troops on July 26 and July 27 in Sagaing Region’s Kani Township, were later found killed with injuries consistent with torture. These men included three men from Kani Town, seven men including a 14 year-old child from Thayet Taw Village, and two men from Kho Twin Village. Their bodies were found in the forest near East Taung Pauk Village in Kani Township on July 31.',
#        'Maung Myint had a mental breakdown due to the kilLinngs and violence in Kani Township and drove a motorbike to Kani Town which is four miles away from Kho Twin Village. When he arrived, he shouted that “our Civilians were killed because of you” and went close to the school wall of B.E.H.S in Kani Town where the junta’s soldiers had set up base. Junta soldiers shot dead the unarmed Maung Myint. His family said the body was hidden by the junta troops that night.'],
#       dtype=object)

# %%
df_4[df_4.organization.str.contains("photo", na=False)]
# Out:
#        no.       name sex  age   father's name date of incident deceased date  \
# 1284  1285  Soe Naing   M  NaN  Unknown \nName        10-Dec-21     13-Dec-21
#
#                             organization      place of incidents  \
# 1284  Profession, Freelance photographer  Interrogation \nCenter
#
#           home address   township states_regions  \
# 1284  Shinsawpu \nWard  Sanchaung         Yangon
#
#                                                 remarks date_of_incident  \
# 1284  On December 13, Soe Naing, a freelance photogr...       2021-12-10
#
#      deceased_date
# 1284    2021-12-13

# %%
df[df.organization.str.contains("photo", na=False)]
# Out:
#        no.       name sex  age   father's name date of incident deceased date  \
# 1284  1285  Soe Naing   M  NaN  Unknown \nName        10-Dec-21     13-Dec-21
#
#                             organization      place of incidents  \
# 1284  Profession, Freelance photographer  Interrogation \nCenter
#
#           home address   township states_regions  \
# 1284  Shinsawpu \nWard  Sanchaung         Yangon
#
#                                                 remarks date_of_incident  \
# 1284  On December 13, Soe Naing, a freelance photogr...       2021-12-10
#
#      deceased_date
# 1284    2021-12-13

# %%
df[df.organization.str.contains("Journalist", na=False)]
# Out:
#        no.           name sex   age   father's name date of incident  \
# 1363  1364  Salai Tui Dim   M  55.0  Unknwon \nName         6-Jan-22
#
#      deceased date                          organization  \
# 1363      8-Jan-22  Media, Journalist (Khonumthung News)
#
#                             place of incidents home address township  \
# 1363  between Kee \nLun and Lawn \nLaw village          NaN   Matupi
#
#      states_regions                                            remarks  \
# 1363           Chin  On January 6 and 7, 10 civilians, including a ...
#
#      date_of_incident deceased_date
# 1363       2022-01-06    2022-01-08

# %%
df[df.organization.str.contains("Media", na=False)]
# Out:
#        no.           name sex   age   father's name date of incident  \
# 1363  1364  Salai Tui Dim   M  55.0  Unknwon \nName         6-Jan-22
#
#      deceased date                          organization  \
# 1363      8-Jan-22  Media, Journalist (Khonumthung News)
#
#                             place of incidents home address township  \
# 1363  between Kee \nLun and Lawn \nLaw village          NaN   Matupi
#
#      states_regions                                            remarks  \
# 1363           Chin  On January 6 and 7, 10 civilians, including a ...
#
#      date_of_incident deceased_date
# 1363       2022-01-06    2022-01-08

# %%
df_3[df_3.remarks.str.contains("shot", na=False)].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 153 entries, 715 to 997
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   no.                 153 non-null    object
#  1   name                153 non-null    object
#  2   sex                 149 non-null    object
#  3   age                 115 non-null    float64
#  4   father's name       153 non-null    object
#  5   date of incident    153 non-null    object
#  6   deceased date       150 non-null    object
#  7   organization        153 non-null    object
#  8   place of incidents  133 non-null    object
#  9   home address        119 non-null    object
#  10  township            139 non-null    object
#  11  states_regions      150 non-null    object
#  12  remarks             153 non-null    object
#  13  date_of_incident    153 non-null    datetime64[ns]
#  14  deceased_date       150 non-null    datetime64[ns]
# ...

# %%
df_4.sort_values("age").head(10)
# Out:
#        no.                name  sex   age   father's name date of incident  \
# 1072  1073        Zwe Htet Maw    M   1.0  Unknown \nName        20-Sep-21
# 1102  1103  Myo Thandar Hlaing    F   5.0     U Myo Naing         1-Oct-21
# 1262  1263     Ei Thandar Aung  NaN   5.0  Unknown \nName         6-Dec-21
# 1138  1139            July San    F   7.0  Unknown \nName        16-Oct-21
# 1009  1010         Jar Zin Tar    F   8.0      U Sar Kamo         7-Sep-21
# 1099  1100            Mar Bone    M   9.0      U Tan Gone        27-Sep-21
# 1120  1121       Thiha Aung\nM  NaN  11.0  Unknown \nName        10-Oct-21
# 1058  1059         Nay Htet Oo   MF  13.0  Unknown \nName        14-Sep-21
# 1250  1251           Arkar Soe    M  14.0  Unknown \nName         7-Dec-21
# 1298  1299           Thar Chit    M  15.0  Unknown \nName        17-Dec-21
#
#      deceased date organization              place of incidents  \
# 1072     20-Sep-21     Civilian                    In The House
# ...

# %%
df_4[df_4.remarks.str.contains("raid", na=False)].sort_values("age").head(20)
# Out:
#        no.                         name  sex   age   father's name  \
# 1072  1073                 Zwe Htet Maw    M   1.0  Unknown \nName
# 1102  1103           Myo Thandar Hlaing    F   5.0     U Myo Naing
# 1120  1121                Thiha Aung\nM  NaN  11.0  Unknown \nName
# 1058  1059                  Nay Htet Oo   MF  13.0  Unknown \nName
# 1250  1251                    Arkar Soe    M  14.0  Unknown \nName
# 1218  1219               Shine Htet Zaw    M  15.0  Unknown \nName
# 1312  1313                    Aung Htay    M  16.0  Unknown \nName
# 1253  1254                 Unknown Name    M  17.0  Unknown \nName
# 1254  1255                    Kyaw Thet    M  17.0  Unknown \nName
# 1057  1058                    Tun Myint    M  17.0  Unknown \nName
# 1251  1252                   San Min Oo    M  17.0  Unknown \nName
# 1252  1253              Than Myint Aung    M  17.0  Unknown \nName
# 1255  1256                  Chit Nan Oo    M  19.0  Unknown \nName
# ...

# %%
df_4[df_4.remarks.str.contains("raid", na=False)].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 109 entries, 1007 to 1381
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   no.                 109 non-null    object
#  1   name                104 non-null    object
#  2   sex                 102 non-null    object
#  3   age                 82 non-null     float64
#  4   father's name       109 non-null    object
#  5   date of incident    109 non-null    object
#  6   deceased date       105 non-null    object
#  7   organization        109 non-null    object
#  8   place of incidents  100 non-null    object
#  9   home address        104 non-null    object
#  10  township            93 non-null     object
#  11  states_regions      108 non-null    object
#  12  remarks             109 non-null    object
#  13  date_of_incident    109 non-null    datetime64[ns]
#  14  deceased_date       105 non-null    datetime64[ns]
# ...

# %%
data = df_4.remarks.to_list()
result = ' '.join(str(s) for s in data)

# %%
words = {}
for word in result.split():
    words[word] = words.get(word, 0) + 1  #

d = [(v, k) for k, v in words.items()]
d.sort()
d.reverse()

for count, word in d[:100]:
    print(count, word)
# Out:
# 887 the
# 704 in
# 600 and
# 453 of
# 393 was
# 387 were
# 379 a
# 320 on
# 300 Village
# 268 shot
# 267 On
# 248 junta
# 239 to
# 222 by
# 202 Township,
# 200 at
# 184 from
# 176 terrorist
# 163 Sagaing
# 156 villagers
# 155 dead
# 138 who
# 135 named
# 135 December
# 126 September
# 124 Aung
# 123 killed
# 122 Region’s
# 119 arrested
# 114 troops
# 113 his
# 107 raided
# 107 October
# 104 when
# 104 old
# 99 local
# 99 armed
# 98 wing
# 95 Maung
# 94 Township
# 94 The
# 93 living
# 91 years
# 91 while
# 91 he
# 86 November
# 84 soldiers
# 84 Region,
# 82 Kyaw
# 81 Zaw
# 77 morning
# 75 their
# 75 including
# 75 Naing
# 73 year
# 72 they
# 71 with
# 64 after
# 64 (cid:10)
# 63 Htay
# 60 Tun
# 59 Htet
# 57 two
# 56 old,
# 56 died
# 56 Min
# 55 Township.
# 55 Myo
# 54 one
# 53 Oo,
# 53 Aung,
# 51 a.k.a
# 51 Win
# 51 They
# 51 Magway
# 49 them
# 49 five
# 49 Junta
# 48 is
# 47 In
# 46 are
# 46 aged
# 45 three
# 45 Myint
# 44 found
# 44 as
# 43 around
# 43 Phyo
# 42 Village.
# ...

# %%
df_4[df_4["place of incidents"].str.contains("Village", na=False)]
# Out:
#        no.         name sex   age   father's name date of incident  \
# 1001  1002    Than Htay   M  35.0         Unknown         1-Sep-21
# 1005  1006      Kan Tun   M  51.0         Unknown         4-Sep-21
# 1006  1007   Khaing Zaw   M  21.0         Unknown         4-Sep-21
# 1007  1008     Khin Zaw   M   NaN         Unknown         5-Sep-21
# 1009  1010  Jar Zin Tar   F   8.0      U Sar Kamo         7-Sep-21
# ...    ...          ...  ..   ...             ...              ...
# 1342  1343     Hla Htoo   M   NaN  Unknown \nName        24-Dec-21
# 1344  1345  Htwar Maung   M  46.0  Unknown \nName        29-Dec-21
# 1377  1378    Thin Htan   M  60.0  Unknown \nName        29-Dec-21
# 1380  1381    Win Myint   M  64.0  Unknown \nName        31-Dec-21
# 1381  1382     Kyaw Thu   M  33.0  Unknown \nName        31-Dec-21
#
#      deceased date                                       organization  \
# 1001      1-Sep-21                                           Civilian
# ...

# %%
df[df.date_of_incident.isnull()].remarks.unique()
# Out:
# array(['In Mandalay, a shipyaroad raid turned violent on Saturday when security forces opened fire on demonstrators trying to stop the arrest of workers taking part in the growing anti-coup movement.',
#        nan,
#        'He was arrested at the beginning of April. He died due to torture on April 5 because of the serious injuries received during interrogation',
#        'On the night of June 20, Kyaw Kyaw Myo, a bridegroom from Lat Pan Hla Village Tract in Mandalay Region’s Singu Township, was shot dead on spot while delivering wedding invitations with his friend by riding a motorcycle. His friend was beaten and also arrested.',
#        'He was shot dead when he did not stop a motorbike while he was riding to Htantabin Township in Yangon Region when the terrorist junta told him to stop. In addition, the junta announced that they found a weapons in his bike’s basket.',
#        'He died while receiving medical treatment at a prison hospital. (cid:10)',
# ...

# %%
df[df.date_of_incident.isnull()].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29 entries, 3 to 1605
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   no.                 29 non-null     object
#  1   name                29 non-null     object
#  2   sex                 29 non-null     object
#  3   age                 16 non-null     float64
#  4   father's name       29 non-null     object
#  5   date of incident    15 non-null     object
#  6   deceased date       24 non-null     object
#  7   organization        29 non-null     object
#  8   place of incidents  27 non-null     object
#  9   home address        19 non-null     object
#  10  township            26 non-null     object
#  11  states_regions      29 non-null     object
#  12  remarks             28 non-null     object
#  13  date_of_incident    0 non-null      datetime64[ns]
#  14  deceased_date       23 non-null     datetime64[ns]
# ...

# %%
df[df.date_of_incident.isnull()]
# Out:
#        no.                              name sex   age  \
# 3        4    Thet Naing Win \n(aka) Min Min   M  37.0
# 205    206                      Zaw Linn Tun   M  28.0
# 603    604                   Ye Min Oo (Tun)   M  32.0
# 830    831                     Kyaw Kyaw Myo   M   NaN
# 838    839                       Aye Min Soe   M  35.0
# 887    888                          Tun Sein   M   NaN
# 960    961                         Kan Htauk   M  72.0
# 966    967                     Soe Lwin Lwin   M  26.0
# 980    981                Salai Oak Hlan Kan   M  14.0
# 1037  1038                      Aung Ko Lwin   M  36.0
# 1098  1099                           Bat Cho   M  37.0
# 1123  1124                     Ei Thet Paing   F   NaN
# 1139  1140                         Ling Choi   M  59.0
# 1364  1365                     Salai La Nang   M  13.0
# 1365  1366                      Salai Steven   M   NaN
# 1366  1367    Salai Van Htoo \n(Mara Native)   M   NaN
# ...
